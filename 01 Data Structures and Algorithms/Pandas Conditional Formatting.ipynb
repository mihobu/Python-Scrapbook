# %%
import pandas as pd

# %%
data = pd.DataFrame([
    ('Abhimanyu',91,56,78,90,87,88),
    ('James',56,65,68,73,67,75),
    ('Emma',88,87,79,90,78,82),
    ('Russ',78,76,73,74,71,77),
    ('Rhea',66,65,69,70,65,61),
    ('Michael',80,45,48,78,83,90),
    ('Adam',34,44,45,55,44,43)
],columns=['Emp Name','January','February','March','April','May','June'])
data
# Out:
#     Emp Name  January  February  March  April  May  June
# 0  Abhimanyu       91        56     78     90   87    88
# 1      James       56        65     68     73   67    75
# 2       Emma       88        87     79     90   78    82
# 3       Russ       78        76     73     74   71    77
# 4       Rhea       66        65     69     70   65    61
# 5    Michael       80        45     48     78   83    90
# 6       Adam       34        44     45     55   44    43

# %%
data.style
# Out:
# <style  type="text/css" >
# </style><table id="T_48a4a38a_c506_11ea_afbb_18dbf24213af" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Emp Name</th>        <th class="col_heading level0 col1" >January</th>        <th class="col_heading level0 col2" >February</th>        <th class="col_heading level0 col3" >March</th>        <th class="col_heading level0 col4" >April</th>        <th class="col_heading level0 col5" >May</th>        <th class="col_heading level0 col6" >June</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_48a4a38a_c506_11ea_afbb_18dbf24213aflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_48a4a38a_c506_11ea_afbb_18dbf24213afrow0_col0" class="data row0 col0" >Abhimanyu</td>
#                         <td id="T_48a4a38a_c506_11ea_afbb_18dbf24213afrow0_col1" class="data row0 col1" >91</td>
# ...

# %%
def highlight(sales):
    color = '#CC0000' if sales > 80 else 'black'
    bgcolor = '#FFFF00' if sales > 80 else '#FFFFFF'
    return 'color: {}; background-color: {};'.format(color,bgcolor)

# %%
data_styler = data.iloc[:,1:6].style.applymap(highlight)
data_styler
# Out:
# <style  type="text/css" >
#     #T_cbe688d2_c506_11ea_9377_18dbf24213afrow0_col0 {
#             color:  #CC0000;
#              background-color:  #FFFF00;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow0_col1 {
#             color:  black;
#              background-color:  #FFFFFF;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow0_col2 {
#             color:  black;
#              background-color:  #FFFFFF;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow0_col3 {
#             color:  #CC0000;
#              background-color:  #FFFF00;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow0_col4 {
#             color:  #CC0000;
#              background-color:  #FFFF00;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow1_col0 {
#             color:  black;
#              background-color:  #FFFFFF;
#         }    #T_cbe688d2_c506_11ea_9377_18dbf24213afrow1_col1 {
#             color:  black;
#              background-color:  #FFFFFF;
# ...

# %%
type(data_formatted)
# Out:
# pandas.io.formats.style.Styler
